# %%
# General import and load data
import pandas as pd
import numpy as np

from pandas import Series, DataFrame

# Training and test spliting
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing

# Estimators
from sklearn.svm import SVC

# Evaluation
from sklearn import metrics
from sklearn.cross_validation import cross_val_score, KFold, StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# Optimization
from sklearn.grid_search import GridSearchCV

# Visualisation
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)


# if matplotlib is not set inline, you will not see plots
#alternatives auto gtk gtk2 inline osx qt qt5 wx tk
#%matplotlib auto
#%matplotlib qt
# %matplotlib inline
# %run plot_learning_curve
# Out:
# C:\Users\grego\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\grego\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# C:\Users\grego\Anaconda3\lib\site-packages\sklearn\learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
#We get a URL with raw content (not HTML one)
df = pd.read_csv('data-churn/train.csv')
df

#No missing values
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0        1062832    Male              0      No         No       1
# 1         675028  Female              0      No         No      50
# 2       11139681    Male              1     Yes         No      59
# 3     1522201755  Female              0      No         No      52
# 4         100644    Male              0     Yes         No      34
# 5     2317128960  Female              1      No         No      30
# 6         411570    Male              0      No         No      52
# 7       11524450    Male              1      No         No      55
# 8        8111899    Male              1     Yes         No      52
# 9      148168345  Female              0     Yes        Yes      69
# 10     104236423    Male              0      No         No       4
# 11        582508  Female              0     Yes         No       2
# 12       9535173  Female              0     Yes         No      35
# 13       1980391    Male              0     Yes        Yes      51
# 14       8199984    Male              0      No         No      36
# 15      21220922    Male              0      No         No      26
# 16    2511240211  Female              0     Yes         No      15
# 17     252086923  Female              0      No         No       2
# 18       8133013    Male              0     Yes         No      53
# 19      33201813  Female              0      No         No      57
# 20     814150179  Female              0     Yes        Yes      71
# 21       5223985  Female              0     Yes        Yes      20
# 22     324254891    Male              0     Yes        Yes      71
# 23     231822803    Male              0      No         No       4
# 24      91206931    Male              0      No         No      30
# 25      23157107  Female              0      No        Yes       1
# 26    1722131776    Male              0     Yes         No      32
# 27       1949726    Male              0      No        Yes      33
# 28       1716269  Female              0      No         No      61
# 29     110127490    Male              0     Yes         No      24
# ...          ...     ...            ...     ...        ...     ...
# 5513   619259673  Female              0      No         No      12
# 5514   211222276  Female              0     Yes        Yes      26
# 5515   241529255  Female              0      No         No       6
# 5516     1980119  Female              0     Yes        Yes      59
# 5517   247227757    Male              0      No        Yes      37
# 5518    17478053  Female              1     Yes         No      28
# 5519    31115577    Male              0      No         No       2
# 5520    14112235    Male              0      No        Yes      12
# 5521   223234132    Male              0      No        Yes      18
# 5522    20171821  Female              0     Yes        Yes      72
# 5523    20025746    Male              0      No         No      16
# 5524     1231900  Female              0     Yes         No      70
# 5525      728703  Female              1     Yes        Yes      28
# 5526     1163436  Female              0      No         No      29
# 5527     6130297  Female              0     Yes        Yes      56
# 5528     1274192    Male              0     Yes         No      47
# 5529     2182802  Female              0     Yes        Yes      10
# 5530      149449  Female              0      No         No      72
# 5531      276127    Male              0     Yes        Yes      25
# 5532  2016236161  Female              1      No         No       8
# 5533   241530879  Female              1      No         No      28
# 5534    15259583    Male              0     Yes        Yes      67
# 5535    32426325  Female              0     Yes         No       3
# 5536     3812754  Female              0      No         No      12
# 5537   141518775    Male              0     Yes        Yes      70
# 5538   241896052    Male              0      No         No      39
# 5539     1917607  Female              0     Yes        Yes      34
# 5540     1651761  Female              0     Yes         No      28
# 5541     8238468    Male              1     Yes         No      69
# 5542     5531185    Male              0      No         No      63
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0             Yes                No              No  No internet service
# 1             Yes               Yes             DSL                   No
# 2             Yes                No     Fiber optic                  Yes
# 3             Yes               Yes             DSL                   No
# 4             Yes               Yes     Fiber optic                   No
# 5             Yes               Yes     Fiber optic                   No
# 6             Yes                No     Fiber optic                  Yes
# 7              No  No phone service             DSL                   No
# 8             Yes                No     Fiber optic                  Yes
# 9              No  No phone service             DSL                   No
# 10            Yes                No     Fiber optic                   No
# 11            Yes                No             DSL                  Yes
# 12            Yes                No             DSL                   No
# 13            Yes                No              No  No internet service
# 14            Yes                No              No  No internet service
# 15            Yes               Yes     Fiber optic                   No
# 16            Yes                No              No  No internet service
# 17            Yes                No     Fiber optic                   No
# 18            Yes               Yes     Fiber optic                   No
# 19            Yes                No             DSL                   No
# 20            Yes               Yes     Fiber optic                  Yes
# 21            Yes                No              No  No internet service
# 22            Yes                No              No  No internet service
# 23             No  No phone service             DSL                  Yes
# 24            Yes               Yes     Fiber optic                   No
# 25            Yes                No             DSL                  Yes
# 26            Yes               Yes     Fiber optic                   No
# 27            Yes                No              No  No internet service
# 28            Yes               Yes             DSL                   No
# 29            Yes                No              No  No internet service
# ...           ...               ...             ...                  ...
# 5513          Yes               Yes     Fiber optic                   No
# 5514           No  No phone service             DSL                  Yes
# 5515          Yes                No     Fiber optic                   No
# 5516          Yes                No             DSL                   No
# 5517          Yes                No             DSL                  Yes
# 5518          Yes               Yes     Fiber optic                   No
# 5519          Yes                No     Fiber optic                   No
# 5520          Yes                No             DSL                  Yes
# 5521          Yes               Yes     Fiber optic                   No
# 5522          Yes               Yes     Fiber optic                  Yes
# 5523          Yes                No              No  No internet service
# 5524          Yes                No             DSL                  Yes
# 5525           No  No phone service             DSL                   No
# 5526           No  No phone service             DSL                   No
# 5527          Yes                No              No  No internet service
# 5528          Yes                No              No  No internet service
# 5529          Yes               Yes     Fiber optic                   No
# 5530          Yes               Yes             DSL                  Yes
# 5531          Yes                No     Fiber optic                   No
# 5532          Yes                No     Fiber optic                   No
# 5533          Yes               Yes             DSL                   No
# 5534          Yes               Yes     Fiber optic                  Yes
# 5535          Yes                No              No  No internet service
# 5536          Yes                No             DSL                   No
# 5537          Yes               Yes             DSL                  Yes
# 5538          Yes                No             DSL                   No
# 5539          Yes                No             DSL                  Yes
# 5540          Yes                No              No  No internet service
# 5541          Yes               Yes     Fiber optic                   No
# 5542          Yes               Yes             DSL                  Yes
#
#       ...      DeviceProtection          TechSupport          StreamingTV  \
# 0     ...   No internet service  No internet service  No internet service
# 1     ...                    No                  Yes                  Yes
# 2     ...                   Yes                   No                   No
# 3     ...                   Yes                  Yes                  Yes
# 4     ...                    No                   No                   No
# 5     ...                    No                   No                  Yes
# 6     ...                   Yes                   No                  Yes
# 7     ...                   Yes                   No                  Yes
# 8     ...                   Yes                  Yes                  Yes
# 9     ...                   Yes                   No                  Yes
# 10    ...                    No                   No                   No
# 11    ...                    No                   No                   No
# 12    ...                    No                  Yes                   No
# 13    ...   No internet service  No internet service  No internet service
# 14    ...   No internet service  No internet service  No internet service
# 15    ...                    No                  Yes                   No
# 16    ...   No internet service  No internet service  No internet service
# 17    ...                    No                   No                   No
# 18    ...                    No                  Yes                   No
# 19    ...                   Yes                  Yes                  Yes
# 20    ...                   Yes                  Yes                   No
# 21    ...   No internet service  No internet service  No internet service
# 22    ...   No internet service  No internet service  No internet service
# 23    ...                    No                  Yes                   No
# 24    ...                    No                  Yes                   No
# 25    ...                    No                  Yes                   No
# 26    ...                   Yes                   No                   No
# 27    ...   No internet service  No internet service  No internet service
# 28    ...                   Yes                  Yes                  Yes
# 29    ...   No internet service  No internet service  No internet service
# ...   ...                   ...                  ...                  ...
# 5513  ...                    No                   No                   No
# 5514  ...                    No                  Yes                   No
# 5515  ...                    No                   No                   No
# 5516  ...                    No                  Yes                  Yes
# 5517  ...                    No                  Yes                   No
# 5518  ...                   Yes                  Yes                  Yes
# 5519  ...                    No                   No                   No
# 5520  ...                    No                   No                  Yes
# 5521  ...                   Yes                   No                   No
# 5522  ...                   Yes                   No                  Yes
# 5523  ...   No internet service  No internet service  No internet service
# 5524  ...                   Yes                  Yes                  Yes
# 5525  ...                    No                   No                   No
# 5526  ...                    No                   No                   No
# 5527  ...   No internet service  No internet service  No internet service
# 5528  ...   No internet service  No internet service  No internet service
# 5529  ...                   Yes                   No                  Yes
# 5530  ...                    No                   No                   No
# 5531  ...                    No                   No                  Yes
# 5532  ...                   Yes                   No                  Yes
# 5533  ...                   Yes                  Yes                   No
# 5534  ...                    No                  Yes                  Yes
# 5535  ...   No internet service  No internet service  No internet service
# 5536  ...                    No                   No                   No
# 5537  ...                   Yes                  Yes                  Yes
# 5538  ...                    No                  Yes                   No
# 5539  ...                   Yes                   No                   No
# 5540  ...   No internet service  No internet service  No internet service
# 5541  ...                   Yes                   No                   No
# 5542  ...                   Yes                  Yes                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 0     No internet service  Month-to-month               No
# 1                     Yes        Two year              Yes
# 2                      No        One year              Yes
# 3                     Yes        Two year              Yes
# 4                     Yes  Month-to-month               No
# 5                     Yes  Month-to-month              Yes
# 6                      No        One year               No
# 7                     Yes        One year              Yes
# 8                     Yes        One year              Yes
# 9                     Yes        Two year              Yes
# 10                    Yes  Month-to-month              Yes
# 11                    Yes  Month-to-month              Yes
# 12                     No  Month-to-month               No
# 13    No internet service        One year               No
# 14    No internet service        Two year              Yes
# 15                     No  Month-to-month              Yes
# 16    No internet service  Month-to-month               No
# 17                     No  Month-to-month               No
# 18                    Yes        One year               No
# 19                     No        Two year               No
# 20                    Yes        Two year               No
# 21    No internet service        One year               No
# 22    No internet service        Two year               No
# 23                     No  Month-to-month               No
# 24                    Yes  Month-to-month              Yes
# 25                     No  Month-to-month              Yes
# 26                     No  Month-to-month              Yes
# 27    No internet service        One year              Yes
# 28                    Yes        Two year               No
# 29    No internet service        One year               No
# ...                   ...             ...              ...
# 5513                  Yes  Month-to-month              Yes
# 5514                   No  Month-to-month               No
# 5515                  Yes  Month-to-month              Yes
# 5516                  Yes        Two year              Yes
# 5517                   No        Two year               No
# 5518                  Yes  Month-to-month              Yes
# 5519                   No  Month-to-month              Yes
# 5520                  Yes  Month-to-month              Yes
# 5521                   No  Month-to-month              Yes
# 5522                  Yes        Two year               No
# 5523  No internet service        Two year               No
# 5524                  Yes        Two year               No
# 5525                  Yes        One year              Yes
# 5526                   No  Month-to-month              Yes
# 5527  No internet service        Two year               No
# 5528  No internet service        One year               No
# 5529                  Yes  Month-to-month              Yes
# 5530                   No        Two year               No
# 5531                  Yes        One year              Yes
# 5532                  Yes  Month-to-month              Yes
# 5533                   No  Month-to-month               No
# 5534                  Yes        Two year               No
# 5535  No internet service  Month-to-month              Yes
# 5536                   No  Month-to-month              Yes
# 5537                   No        Two year              Yes
# 5538                   No        Two year              Yes
# 5539                   No        One year              Yes
# 5540  No internet service  Month-to-month               No
# 5541                  Yes  Month-to-month              Yes
# 5542                   No        One year               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 0       Credit card (automatic)          20.55         20.55     0
# 1                  Mailed check          79.60        4024.2     0
# 2       Credit card (automatic)          82.95       4903.15     0
# 3     Bank transfer (automatic)          80.95       4233.95     0
# 4                  Mailed check          88.85       3000.25     0
# 5              Electronic check          99.70       2967.35     1
# 6              Electronic check          91.25        4738.3     0
# 7     Bank transfer (automatic)          50.05       2743.45     0
# 8     Bank transfer (automatic)         104.45       5481.25     0
# 9       Credit card (automatic)          54.95        3772.5     0
# 10             Electronic check          79.90         324.3     1
# 11                 Mailed check          62.15         113.1     0
# 12             Electronic check          56.85        1861.1     0
# 13                 Mailed check          19.40        997.75     0
# 14      Credit card (automatic)          18.55           689     0
# 15             Electronic check          80.50        2088.8     1
# 16      Credit card (automatic)          20.45         330.8     0
# 17    Bank transfer (automatic)          70.00        153.05     1
# 18    Bank transfer (automatic)          97.75        5043.2     0
# 19                 Mailed check          69.75        3894.4     0
# 20             Electronic check         100.45        7159.7     0
# 21    Bank transfer (automatic)          19.70         395.6     0
# 22                 Mailed check          19.45       1378.45     0
# 23                 Mailed check          42.40         146.4     0
# 24      Credit card (automatic)          89.90       2723.15     0
# 25             Electronic check          60.00            60     1
# 26             Electronic check          78.90       2447.95     1
# 27                 Mailed check          20.15        682.15     0
# 28      Credit card (automatic)          88.65       5321.25     0
# 29                 Mailed check          20.10         533.9     0
# ...                         ...            ...           ...   ...
# 5513           Electronic check          86.55        1066.9     0
# 5514    Credit card (automatic)          38.85       1025.15     0
# 5515               Mailed check          85.95         514.6     0
# 5516    Credit card (automatic)          75.95       4542.35     0
# 5517    Credit card (automatic)          61.45       2302.35     0
# 5518           Electronic check         110.85        3204.4     0
# 5519    Credit card (automatic)          71.30        157.75     0
# 5520               Mailed check          69.85         837.5     0
# 5521    Credit card (automatic)          80.55       1406.65     0
# 5522    Credit card (automatic)         109.55       7887.25     0
# 5523               Mailed check          19.75        284.35     0
# 5524    Credit card (automatic)          86.45        5950.2     0
# 5525           Electronic check          39.10        1096.6     0
# 5526    Credit card (automatic)          25.10        712.85     1
# 5527               Mailed check          20.05        1090.1     0
# 5528  Bank transfer (automatic)          19.90        942.95     0
# 5529    Credit card (automatic)         102.10       1068.85     1
# 5530  Bank transfer (automatic)          59.75          4265     0
# 5531           Electronic check          90.40        2178.6     1
# 5532           Electronic check          92.10        729.95     1
# 5533  Bank transfer (automatic)          64.45        1867.6     0
# 5534  Bank transfer (automatic)         104.60       6885.75     0
# 5535               Mailed check          19.60         55.25     0
# 5536  Bank transfer (automatic)          45.00        524.35     0
# 5537  Bank transfer (automatic)          79.25       5731.85     0
# 5538  Bank transfer (automatic)          49.80       1971.15     0
# 5539               Mailed check          60.80       2042.05     0
# 5540               Mailed check          20.50        563.05     0
# 5541  Bank transfer (automatic)          95.35          6382     0
# 5542  Bank transfer (automatic)          68.80       4111.35     0
#
# [5543 rows x 21 columns]

# %%
df.loc[df["gender"] == "Male", "gender"] = 0
df.loc[df["gender"] == "Female", "gender"] = 1

df.loc[df["Partner"] == "Yes", "Partner"] = 1
df.loc[df["Partner"] == "No", "Partner"] = 0

df.loc[df["Dependents"] == "Yes", "Dependents"] = 1
df.loc[df["Dependents"] == "No", "Dependents"] = 0

df.loc[df["PhoneService"] == "Yes", "PhoneService"] = 1
df.loc[df["PhoneService"] == "No", "PhoneService"] = 0

df.loc[df["MultipleLines"] == "No", "MultipleLines"] = 0
df.loc[df["MultipleLines"] == "No phone service", "MultipleLines"] = 0
df.loc[df["MultipleLines"] == "Yes", "MultipleLines"] = 1

df.loc[df["InternetService"] == "No", "InternetService"] = 0
df.loc[df["InternetService"] == "DSL", "InternetService"] = 1
df.loc[df["InternetService"] == "Fiber optic", "InternetService"] = 2

df.loc[df["OnlineSecurity"] == "No", "OnlineSecurity"] = 0
df.loc[df["OnlineSecurity"] == "No internet service", "OnlineSecurity"] = 0
df.loc[df["OnlineSecurity"] == "Yes", "OnlineSecurity"] = 1

df.loc[df["OnlineBackup"] == "No", "OnlineBackup"] = 0
df.loc[df["OnlineBackup"] == "No internet service", "OnlineBackup"] = 0
df.loc[df["OnlineBackup"] == "Yes", "OnlineBackup"] = 1

df.loc[df["DeviceProtection"] == "No", "DeviceProtection"] = 0
df.loc[df["DeviceProtection"] == "No internet service", "DeviceProtection"] = 0
df.loc[df["DeviceProtection"] == "Yes", "DeviceProtection"] = 1

df.loc[df["TechSupport"] == "No", "TechSupport"] = 0
df.loc[df["TechSupport"] == "No internet service", "TechSupport"] = 0
df.loc[df["TechSupport"] == "Yes", "TechSupport"] = 1

df.loc[df["StreamingTV"] == "No", "StreamingTV"] = 0
df.loc[df["StreamingTV"] == "No internet service", "StreamingTV"] = 0
df.loc[df["StreamingTV"] == "Yes", "StreamingTV"] = 1

df.loc[df["StreamingMovies"] == "No", "StreamingMovies"] = 0
df.loc[df["StreamingMovies"] == "No internet service", "StreamingMovies"] = 0
df.loc[df["StreamingMovies"] == "Yes", "StreamingMovies"] = 1

df.loc[df["Contract"] == "Two year", "Contract"] = 0
df.loc[df["Contract"] == "One year", "Contract"] = 1
df.loc[df["Contract"] == "Month-to-month", "Contract"] = 2

df.loc[df["PaperlessBilling"] == "Yes", "PaperlessBilling"] = 1
df.loc[df["PaperlessBilling"] == "No", "PaperlessBilling"] = 0

df.loc[df["PaymentMethod"] == "Bank transfer (automatic)", "PaymentMethod"] = 0
df.loc[df["PaymentMethod"] == "Mailed check", "PaymentMethod"] = 1
df.loc[df["PaymentMethod"] == "Electronic check", "PaymentMethod"] = 2
df.loc[df["PaymentMethod"] == "Credit card (automatic)", "PaymentMethod"] = 3

df["TotalCharges"] = df["TotalCharges"].apply(pd.to_numeric, errors='coerce')
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

df[-5:]
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 5538   241896052       0              0        0           0      39
# 5539     1917607       1              0        1           1      34
# 5540     1651761       1              0        1           0      28
# 5541     8238468       0              1        1           0      69
# 5542     5531185       0              0        0           0      63
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...    \
# 5538             1              0                1               0  ...
# 5539             1              0                1               1  ...
# 5540             1              0                0               0  ...
# 5541             1              1                2               0  ...
# 5542             1              1                1               1  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 5538                 0            1            0                0         0
# 5539                 1            0            0                0         1
# 5540                 0            0            0                0         2
# 5541                 1            0            0                1         2
# 5542                 1            1            0                0         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 5538                 1              0           49.80       1971.15      0
# 5539                 1              1           60.80       2042.05      0
# 5540                 0              1           20.50        563.05      0
# 5541                 1              0           95.35       6382.00      0
# 5542                 0              0           68.80       4111.35      0
#
# [5 rows x 21 columns]

# %%
df['gender'] = df['gender'].astype(np.int64)
df['Partner'] = df['Partner'].astype(np.int64)
df['Dependents'] = df['Dependents'].astype(np.int64)
df['PhoneService'] = df['PhoneService'].astype(np.int64)
df['MultipleLines'] = df['MultipleLines'].astype(np.int64)
df['InternetService'] = df['InternetService'].astype(np.int64)
df['OnlineSecurity'] = df['OnlineSecurity'].astype(np.int64)
df['OnlineBackup'] = df['OnlineBackup'].astype(np.int64)
df['DeviceProtection'] = df['DeviceProtection'].astype(np.float64)
df['TechSupport'] = df['TechSupport'].astype(np.int64)
df['StreamingTV'] = df['StreamingTV'].astype(np.int64)
df['StreamingMovies'] = df['StreamingMovies'].astype(np.int64)
df['Contract'] = df['Contract'].astype(np.int64)
df['PaperlessBilling'] = df['PaperlessBilling'].astype(np.int64)
df['PaymentMethod'] = df['PaymentMethod'].astype(np.int64)
df.dtypes
# Out:
# customerID            int64
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService       int64
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection    float64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract              int64
# PaperlessBilling      int64
# PaymentMethod         int64
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
# Features of the model

features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines','InternetService',
           'OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract',
           'PaperlessBilling','PaymentMethod','MonthlyCharges', 'TotalCharges']
# Transform dataframe in numpy arrays
X = df[features].values
y = df['Churn'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)

# %% [markdown]
# # Define model GNB

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

model=gnb.fit(X_train, y_train)

predicted = model.predict(X_test)
churn=predicted
expected = y_test

# %%
# Accuracy
metrics.accuracy_score(expected, predicted)
# Out:
# 0.7980162308385933

# %%
preliminaryResult = df.filter(['customerID'], axis=1)

# %% [markdown]
# # Confusion Matrix

# %% [markdown]
# To get tp, tn, fp and fn

# %% [markdown]
# F1=2*p*r/(p+r)  where  p=tp/(tp+fp),  r=tp/(tp+fn)

# %%
#[[tn fp][fn tp]]
cMatrix=metrics.confusion_matrix(expected, predicted)
trueN=cMatrix[0,0]
falseP=cMatrix[0,1]
falseN=cMatrix[1,0]
trueP=cMatrix[1,1]

# %%
p=trueP/(trueP+falseP)
r=trueP/(trueP)
F1=(2*p*r)/(p+r)
F1
# Out:
# 0.7602523659305993

# %% [markdown]
# # To CSV

# %%
dfTest = pd.read_csv('data-churn/test_nolabel.csv')

# %%
dfTest.loc[dfTest["gender"] == "Male", "gender"] = 0
dfTest.loc[dfTest["gender"] == "Female", "gender"] = 1

dfTest.loc[dfTest["Partner"] == "Yes", "Partner"] = 1
dfTest.loc[dfTest["Partner"] == "No", "Partner"] = 0

dfTest.loc[dfTest["Dependents"] == "Yes", "Dependents"] = 1
dfTest.loc[dfTest["Dependents"] == "No", "Dependents"] = 0

dfTest.loc[dfTest["PhoneService"] == "Yes", "PhoneService"] = 1
dfTest.loc[dfTest["PhoneService"] == "No", "PhoneService"] = 0

dfTest.loc[dfTest["MultipleLines"] == "No", "MultipleLines"] = 0
dfTest.loc[dfTest["MultipleLines"] == "No phone service", "MultipleLines"] = 0
dfTest.loc[dfTest["MultipleLines"] == "Yes", "MultipleLines"] = 1

dfTest.loc[dfTest["InternetService"] == "No", "InternetService"] = 0
dfTest.loc[dfTest["InternetService"] == "DSL", "InternetService"] = 1
dfTest.loc[dfTest["InternetService"] == "Fiber optic", "InternetService"] = 2

dfTest.loc[dfTest["OnlineSecurity"] == "No", "OnlineSecurity"] = 0
dfTest.loc[dfTest["OnlineSecurity"] == "No internet service", "OnlineSecurity"] = 0
dfTest.loc[dfTest["OnlineSecurity"] == "Yes", "OnlineSecurity"] = 1

dfTest.loc[dfTest["OnlineBackup"] == "No", "OnlineBackup"] = 0
dfTest.loc[dfTest["OnlineBackup"] == "No internet service", "OnlineBackup"] = 0
dfTest.loc[dfTest["OnlineBackup"] == "Yes", "OnlineBackup"] = 1

dfTest.loc[dfTest["DeviceProtection"] == "No", "DeviceProtection"] = 0
dfTest.loc[dfTest["DeviceProtection"] == "No internet service", "DeviceProtection"] = 0
dfTest.loc[dfTest["DeviceProtection"] == "Yes", "DeviceProtection"] = 1

dfTest.loc[dfTest["TechSupport"] == "No", "TechSupport"] = 0
dfTest.loc[dfTest["TechSupport"] == "No internet service", "TechSupport"] = 0
dfTest.loc[dfTest["TechSupport"] == "Yes", "TechSupport"] = 1

dfTest.loc[dfTest["StreamingTV"] == "No", "StreamingTV"] = 0
dfTest.loc[dfTest["StreamingTV"] == "No internet service", "StreamingTV"] = 0
dfTest.loc[dfTest["StreamingTV"] == "Yes", "StreamingTV"] = 1

dfTest.loc[dfTest["StreamingMovies"] == "No", "StreamingMovies"] = 0
dfTest.loc[dfTest["StreamingMovies"] == "No internet service", "StreamingMovies"] = 0
dfTest.loc[dfTest["StreamingMovies"] == "Yes", "StreamingMovies"] = 1

dfTest.loc[dfTest["Contract"] == "Two year", "Contract"] = 0
dfTest.loc[dfTest["Contract"] == "One year", "Contract"] = 1
dfTest.loc[dfTest["Contract"] == "Month-to-month", "Contract"] = 2

dfTest.loc[dfTest["PaperlessBilling"] == "Yes", "PaperlessBilling"] = 1
dfTest.loc[dfTest["PaperlessBilling"] == "No", "PaperlessBilling"] = 0

dfTest.loc[dfTest["PaymentMethod"] == "Bank transfer (automatic)", "PaymentMethod"] = 0
dfTest.loc[dfTest["PaymentMethod"] == "Mailed check", "PaymentMethod"] = 1
dfTest.loc[dfTest["PaymentMethod"] == "Electronic check", "PaymentMethod"] = 2
dfTest.loc[dfTest["PaymentMethod"] == "Credit card (automatic)", "PaymentMethod"] = 3

dfTest["TotalCharges"] = dfTest["TotalCharges"].apply(pd.to_numeric, errors='coerce')
dfTest['TotalCharges'] = dfTest['TotalCharges'].fillna(dfTest['TotalCharges'].median())
dfTest.drop(['customerID'],axis=1,inplace=True)
dfTest[-5:]

dfTest['gender'] = dfTest['gender'].astype(np.int64)
dfTest['Partner'] = dfTest['Partner'].astype(np.int64)
dfTest['Dependents'] = dfTest['Dependents'].astype(np.int64)
dfTest['PhoneService'] = dfTest['PhoneService'].astype(np.int64)
dfTest['MultipleLines'] = dfTest['MultipleLines'].astype(np.int64)
dfTest['InternetService'] = dfTest['InternetService'].astype(np.int64)
dfTest['OnlineSecurity'] = dfTest['OnlineSecurity'].astype(np.int64)
dfTest['OnlineBackup'] = dfTest['OnlineBackup'].astype(np.int64)
dfTest['DeviceProtection'] = dfTest['DeviceProtection'].astype(np.float64)
dfTest['TechSupport'] = dfTest['TechSupport'].astype(np.int64)
dfTest['StreamingTV'] = dfTest['StreamingTV'].astype(np.int64)
dfTest['StreamingMovies'] = dfTest['StreamingMovies'].astype(np.int64)
dfTest['Contract'] = dfTest['Contract'].astype(np.int64)
dfTest['PaperlessBilling'] = dfTest['PaperlessBilling'].astype(np.int64)
dfTest['PaymentMethod'] = dfTest['PaymentMethod'].astype(np.int64)
dfTest.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService       int64
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection    float64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract              int64
# PaperlessBilling      int64
# PaymentMethod         int64
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %%
dataframeResult = pd.read_csv('./data-churn/test_nolabel.csv').filter(['customerID'], axis=1)
churn = gnb.predict(dfTest)
dataframeResult['Churn'] = churn
dataframeResult[:]
# Out:
#       customerID  Churn
# 0       21135993      0
# 1       13130474      0
# 2        7533169      1
# 3     2114231208      0
# 4        3524728      1
# 5      192125049      0
# 6      172428986      1
# 7       21329444      0
# 8      232256498      1
# 9      162223094      1
# 10      51038704      1
# 11       3192991      0
# 12      14207440      1
# 13      16148243      0
# 14     151417704      1
# 15       9638888      1
# 16    1824179531      1
# 17       9183692      1
# 18     102305485      0
# 19      38229369      1
# 20     171172457      0
# 21      62027146      0
# 22     222524938      1
# 23     122574217      0
# 24      22166710      0
# 25      25129125      0
# 26     316156156      0
# 27     231726750      0
# 28       2185655      1
# 29      12189076      1
# ...          ...    ...
# 1470     1380287      0
# 1471     3029366      0
# 1472   221821377      0
# 1473   610239047      1
# 1474    21139551      0
# 1475     1782114      0
# 1476     8192630      0
# 1477  1323170139      0
# 1478   141961567      1
# 1479   192162726      1
# 1480   152133397      0
# 1481      304169      0
# 1482    64150263      0
# 1483     1212551      0
# 1484   232226447      0
# 1485     5197900      0
# 1486  2513179236      0
# 1487  2224140284      0
# 1488    71331462      0
# 1489   114216100      0
# 1490    11021410      1
# 1491     4317247      0
# 1492   221527250      1
# 1493   122319988      0
# 1494   122143163      1
# 1495  1014207636      0
# 1496    17133913      1
# 1497    14165210      0
# 1498    24777679      1
# 1499   161514055      0
#
# [1500 rows x 2 columns]

# %%
dataframeResult.to_csv('out_gnb.csv', sep=',', index=False)
